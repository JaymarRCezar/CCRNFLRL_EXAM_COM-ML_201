# %% [markdown]
# ### **Jaymar R.Cezar**

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Machine Problem 1

# %% [markdown]
# 1. Create your own environment by constructing the maze in the image below.
# 2. Find the optimal policy to exit depicted by a star in the maze.

# %% [markdown]
# ![MAZE.jpg](data:image/jpeg;base64,...)

# %%
class gridworld:
    
    def __init__(self):
        self.dim = [13, 12]
        self.pos_A = [3, 0]
        self.rew_A = 15

        # Define starting position
        self.start = [11, 10]
        self.s = self.start[:]
        self.reward = 0

        # Define the position of the walls here
        self.wallA = [0, 0]
        self.wallB = [0, 1]
        self.wallC = [0, 2]
        self.wallD = [0, 3]
        self.wallE = [0, 4]
        self.wallF = [0, 5]
        self.wallG = [0, 6]
        self.wallH = [0, 7]
        self.wallI = [0, 9]
        self.wallJ = [0, 10]
        self.wallK = [0, 11]
        self.wallL = [1, 11]
        self.wallM = [2, 11]
        self.wallN = [3, 11]
        self.wallO = [4, 11]
        self.wallP = [5, 11]
        self.wallQ = [6, 11]
        self.wallR = [7, 11]
        self.wallS = [8, 11]
        self.wallT = [9, 11]
        self.wallU = [10, 11]
        self.wallV = [11, 11]
        self.wallW = [1, 9]
        self.wallX = [2, 9]
        self.wallY = [4, 9]
        self.wallZ = [5, 9]
        self.walla = [6, 9]
        self.wallb = [7, 9]
        self.wallc = [8, 9]
        self.walld = [10, 9]
        self.walle = [1, 7]
        self.wallf = [2, 7]
        self.wallg = [3, 7]
        self.wallh = [4, 7]
        self.walli = [6, 7]
        self.wallj = [7, 7]
        self.wallk = [8, 7]
        self.walll = [9, 7]
        self.wallm = [10, 7]
        self.walln = [4, 8]
        self.wallo = [10, 8]
        self.wallp = [4, 0]
        self.wallq = [4, 1]
        self.wallr = [4, 2]
        self.walls = [4, 4]
        self.wallt = [4, 5]
        self.wallu = [4, 6]
        self.wallv = [1, 0]
        self.wallw = [2, 0]
        self.wallx = [5, 0]
        self.wally = [6, 0]
        self.wallz = [7, 0]
        self.wallaa = [8, 0]
        self.wallbb = [9, 0]
        self.wallcc = [10, 0]
        self.walldd = [11, 0]
        self.wallee = [2, 1]
        self.wallff = [2, 2]
        self.wallgg = [2, 3]
        self.wallhh = [2, 4]
        self.wallii = [2, 5]
        self.walljj = [5, 4]
        self.wallkk = [6, 4]
        self.wallll = [7, 4]
        self.wallmm = [8, 4]
        self.wallnn = [8, 5]
        self.walloo = [6, 2]
        self.wallpp = [6, 2]
        self.wallqq = [7, 2]
        self.wallrr = [8, 2]
        self.wallss = [9, 2]
        self.walltt = [10, 2]
        self.walluu = [11, 2]
        self.wallvv = [10, 3]
        self.wallww = [10, 4]
        self.wallxx = [10, 5]
        self.wallyy = [10, 6]
        self.wallzz = [6, 6]
        self.wall1 = [12, 0]
        self.wall2 = [12, 1]
        self.wall3 = [12, 2]
        self.wall4 = [12, 3]
        self.wall5 = [12, 4]
        self.wall6 = [12, 5]
        self.wall7 = [12, 6]
        self.wall8 = [12, 7]
        self.wall9 = [12, 8]
        self.wall10 = [12, 9]
        self.wall11 = [12, 10]
        self.wall12 = [12, 11]


        # Step count
        self.n = 0
        self.action_space = ["U", "L", "D", "R"]
        self.action_prob = [0.25, 0.25, 0.25, 0.25]
    
    # Show empty environment
    def show_grid(self):
        # print rows
        for i in range(self.dim[0]):
            print("-" * (self.dim[0] * 5 + 1))
            row = []
            for j in range(self.dim[1]):
                if i == self.pos_A[0] and j == self.pos_A[1]:
                    row.append("| A ")
                elif i == self.start[0] and j == self.start[1]:
                    row.append("| S ")  
                elif i == self.wallA[0] and j == self.wallA[1]:
                    row.append("| W ")
                elif i == self.wallB[0] and j == self.wallB[1]:
                  row.append("| W ")   
                elif i == self.wallC[0] and j == self.wallC[1]:
                  row.append("| W ")        
                elif i == self.wallD[0] and j == self.wallD[1]:
                  row.append("| W ")    
                elif i == self.wallE[0] and j == self.wallE[1]:
                  row.append("| W ")    
                elif i == self.wallF[0] and j == self.wallF[1]:
                  row.append("| W ")    
                elif i == self.wallG[0] and j == self.wallG[1]:
                  row.append("| W ")  
                elif i == self.wallH[0] and j == self.wallH[1]:
                  row.append("| W ")
                elif i == self.wallI[0] and j == self.wallI[1]:
                  row.append("| W ")   
                elif i == self.wallJ[0] and j == self.wallJ[1]:
                  row.append("| W ")    
                elif i == self.wallK[0] and j == self.wallK[1]:
                  row.append("| W ") 
                elif i == self.wallL[0] and j == self.wallL[1]:
                  row.append("| W ")   
                elif i == self.wallM[0] and j == self.wallM[1]:
                  row.append("| W ")        
                elif i == self.wallN[0] and j == self.wallN[1]:
                  row.append("| W ")    
                elif i == self.wallO[0] and j == self.wallO[1]:
                  row.append("| W ")    
                elif i == self.wallP[0] and j == self.wallP[1]:
                  row.append("| W ")    
                elif i == self.wallQ[0] and j == self.wallQ[1]:
                  row.append("| W ")  
                elif i == self.wallR[0] and j == self.wallR[1]:
                  row.append("| W ")
                elif i == self.wallS[0] and j == self.wallS[1]:
                  row.append("| W ")   
                elif i == self.wallT[0] and j == self.wallT[1]:
                  row.append("| W ")    
                elif i == self.wallU[0] and j == self.wallU[1]:
                  row.append("| W ")  
                elif i == self.wallV[0] and j == self.wallV[1]:
                  row.append("| W ")  
                elif i == self.wallW[0] and j == self.wallW[1]:
                  row.append("| W ")
                elif i == self.wallX[0] and j == self.wallX[1]:
                  row.append("| W ")   
                elif i == self.wallY[0] and j == self.wallY[1]:
                  row.append("| W ")    
                elif i == self.wallZ[0] and j == self.wallZ[1]:
                  row.append("| W ")  
                elif i == self.walla[0] and j == self.walla[1]:
                  row.append("| W ")  
                elif i == self.wallb[0] and j == self.wallb[1]:
                  row.append("| W ")  
                elif i == self.wallc[0] and j == self.wallc[1]:
                  row.append("| W ")  
                elif i == self.walld[0] and j == self.walld[1]:
                  row.append("| W ")  
                elif i == self.walle[0] and j == self.walle[1]:
                  row.append("| W ")  
                elif i == self.wallf[0] and j == self.wallf[1]:
                  row.append("| W ")  
                elif i == self.wallg[0] and j == self.wallg[1]:
                  row.append("| W ")  
                elif i == self.wallh[0] and j == self.wallh[1]:
                  row.append("| W ")  
                elif i == self.walli[0] and j == self.walli[1]:
                  row.append("| W ")  
                elif i == self.wallj[0] and j == self.wallj[1]:
                  row.append("| W ")  
                elif i == self.wallk[0] and j == self.wallk[1]:
                  row.append("| W ")  
                elif i == self.walll[0] and j == self.walll[1]:
                  row.append("| W ")  
                elif i == self.wallm[0] and j == self.wallm[1]:
                  row.append("| W ")  
                elif i == self.walln[0] and j == self.walln[1]:
                  row.append("| W ")  
                elif i == self.wallo[0] and j == self.wallo[1]:
                  row.append("| W ")  
                elif i == self.wallp[0] and j == self.wallp[1]:
                    row.append("| W ")
                elif i == self.wallq[0] and j == self.wallq[1]:
                    row.append("| W ")
                elif i == self.wallr[0] and j == self.wallr[1]:
                    row.append("| W ")
                elif i == self.walls[0] and j == self.walls[1]:
                    row.append("| W ")
                elif i == self.wallt[0] and j == self.wallt[1]:
                    row.append("| W ")
                elif i == self.wallu[0] and j == self.wallu[1]:
                    row.append("| W ")
                elif i == self.wallv[0] and j == self.wallv[1]:
                    row.append("| W ")
                elif i == self.wallw[0] and j == self.wallw[1]:
                    row.append("| W ")
                elif i == self.wallx[0] and j == self.wallx[1]:
                    row.append("| W ")
                elif i == self.wally[0] and j == self.wally[1]:
                    row.append("| W ")
                elif i == self.wallz[0] and j == self.wallz[1]:
                    row.append("| W ")
                elif i == self.wallaa[0] and j == self.wallaa[1]:
                    row.append("| W ")
                elif i == self.wallbb[0] and j == self.wallbb[1]:
                    row.append("| W ")
                elif i == self.wallcc[0] and j == self.wallcc[1]:
                    row.append("| W ")
                elif i == self.walldd[0] and j == self.walldd[1]:
                    row.append("| W ")
                elif i == self.wallee[0] and j == self.wallee[1]:
                    row.append("| W ")
                elif i == self.wallff[0] and j == self.wallff[1]:
                    row.append("| W ")
                elif i == self.wallgg[0] and j == self.wallgg[1]:
                    row.append("| W ")
                elif i == self.wallhh[0] and j == self.wallhh[1]:
                    row.append("| W ")
                elif i == self.wallii[0] and j == self.wallii[1]:
                    row.append("| W ")
                elif i == self.walljj[0] and j == self.walljj[1]:
                    row.append("| W ")
                elif i == self.wallkk[0] and j == self.wallkk[1]:
                    row.append("| W ")
                elif i == self.wallll[0] and j == self.wallll[1]:
                    row.append("| W ")
                elif i == self.wallmm[0] and j == self.wallmm[1]:
                    row.append("| W ")
                elif i == self.wallnn[0] and j == self.wallnn[1]:
                    row.append("| W ")
                elif i == self.walloo[0] and j == self.walloo[1]:
                    row.append("| W ")
                elif i == self.wallpp[0] and j == self.wallpp[1]:
                    row.append("| W ")
                elif i == self.wallqq[0] and j == self.wallqq[1]:
                    row.append("| W ")
                elif i == self.wallrr[0] and j == self.wallrr[1]:
                    row.append("| W ")
                elif i == self.wallss[0] and j == self.wallss[1]:
                    row.append("| W ")
                elif i == self.walltt[0] and j == self.walltt[1]:
                    row.append("| W ")
                elif i == self.walluu[0] and j == self.walluu[1]:
                    row.append("| W ")
                elif i == self.wallvv[0] and j == self.wallvv[1]:
                    row.append("| W ")
                elif i == self.wallww[0] and j == self.wallww[1]:
                    row.append("| W ")
                elif i == self.wallxx[0] and j == self.wallxx[1]:
                    row.append("| W ")
                elif i == self.wallyy[0] and j == self.wallyy[1]:
                    row.append("| W ")
                elif i == self.wallzz[0] and j == self.wallzz[1]:
                    row.append("| W ")
                elif i == self.wall1[0] and j == self.wall1[1]:
                    row.append("| W ")
                elif i == self.wall2[0] and j == self.wall2[1]:
                    row.append("| W ")
                elif i == self.wall3[0] and j == self.wall3[1]:
                    row.append("| W ")
                elif i == self.wall4[0] and j == self.wall4[1]:
                    row.append("| W ")
                elif i == self.wall5[0] and j == self.wall5[1]:
                    row.append("| W ")
                elif i == self.wall6[0] and j == self.wall6[1]:
                    row.append("| W ")
                elif i == self.wall7[0] and j == self.wall7[1]:
                    row.append("| W ")
                elif i == self.wall8[0] and j == self.wall8[1]:
                    row.append("| W ")
                elif i == self.wall9[0] and j == self.wall9[1]:
                    row.append("| W ")
                elif i == self.wall10[0] and j == self.wall10[1]:
                    row.append("| W ")
                elif i == self.wall11[0] and j == self.wall11[1]:
                    row.append("| W ")
                elif i == self.wall12[0] and j == self.wall12[1]:
                    row.append("| W ")
                else:
                    row.append("|   ")
            row.append("|  ")
            print(' '.join(row))
        print("-" * (self.dim[0] * 12 + 1))
        
    # Show state
    def show_state(self):
        # print rows
        for i in range(self.dim[0]):
            print("-" * (self.dim[0] * 5 + 1))
            row = []
            for j in range(self.dim[1]):
                if i == self.s[0] and j == self.s[1]:
                    row.append("| X ")
                elif i == self.pos_A[0] and j == self.pos_A[1]:
                    row.append("| A ")   
                elif i == self.wallA[0] and j == self.wallA[1]:
                    row.append("| W ")
                elif i == self.wallB[0] and j == self.wallB[1]:
                  row.append("| W ")   
                elif i == self.wallC[0] and j == self.wallC[1]:
                  row.append("| W ")        
                elif i == self.wallD[0] and j == self.wallD[1]:
                  row.append("| W ")    
                elif i == self.wallE[0] and j == self.wallE[1]:
                  row.append("| W ")    
                elif i == self.wallF[0] and j == self.wallF[1]:
                  row.append("| W ")    
                elif i == self.wallG[0] and j == self.wallG[1]:
                  row.append("| W ")  
                elif i == self.wallH[0] and j == self.wallH[1]:
                  row.append("| W ")
                elif i == self.wallI[0] and j == self.wallI[1]:
                  row.append("| W ")   
                elif i == self.wallJ[0] and j == self.wallJ[1]:
                  row.append("| W ")    
                elif i == self.wallK[0] and j == self.wallK[1]:
                  row.append("| W ") 
                elif i == self.wallL[0] and j == self.wallL[1]:
                  row.append("| W ")   
                elif i == self.wallM[0] and j == self.wallM[1]:
                  row.append("| W ")        
                elif i == self.wallN[0] and j == self.wallN[1]:
                  row.append("| W ")    
                elif i == self.wallO[0] and j == self.wallO[1]:
                  row.append("| W ")    
                elif i == self.wallP[0] and j == self.wallP[1]:
                  row.append("| W ")    
                elif i == self.wallQ[0] and j == self.wallQ[1]:
                  row.append("| W ")  
                elif i == self.wallR[0] and j == self.wallR[1]:
                  row.append("| W ")
                elif i == self.wallS[0] and j == self.wallS[1]:
                  row.append("| W ")   
                elif i == self.wallT[0] and j == self.wallT[1]:
                  row.append("| W ")    
                elif i == self.wallU[0] and j == self.wallU[1]:
                  row.append("| W ")  
                elif i == self.wallV[0] and j == self.wallV[1]:
                  row.append("| W ")  
                elif i == self.wallW[0] and j == self.wallW[1]:
                  row.append("| W ")
                elif i == self.wallX[0] and j == self.wallX[1]:
                  row.append("| W ")   
                elif i == self.wallY[0] and j == self.wallY[1]:
                  row.append("| W ")    
                elif i == self.wallZ[0] and j == self.wallZ[1]:
                  row.append("| W ")  
                elif i == self.walla[0] and j == self.walla[1]:
                  row.append("| W ")  
                elif i == self.wallb[0] and j == self.wallb[1]:
                  row.append("| W ")  
                elif i == self.wallc[0] and j == self.wallc[1]:
                  row.append("| W ")  
                elif i == self.walld[0] and j == self.walld[1]:
                  row.append("| W ")  
                elif i == self.walle[0] and j == self.walle[1]:
                  row.append("| W ")  
                elif i == self.wallf[0] and j == self.wallf[1]:
                  row.append("| W ")  
                elif i == self.wallg[0] and j == self.wallg[1]:
                  row.append("| W ")  
                elif i == self.wallh[0] and j == self.wallh[1]:
                  row.append("| W ")  
                elif i == self.walli[0] and j == self.walli[1]:
                  row.append("| W ")  
                elif i == self.wallj[0] and j == self.wallj[1]:
                  row.append("| W ")  
                elif i == self.wallk[0] and j == self.wallk[1]:
                  row.append("| W ")  
                elif i == self.walll[0] and j == self.walll[1]:
                  row.append("| W ")  
                elif i == self.wallm[0] and j == self.wallm[1]:
                  row.append("| W ")  
                elif i == self.walln[0] and j == self.walln[1]:
                  row.append("| W ")  
                elif i == self.wallo[0] and j == self.wallo[1]:
                  row.append("| W ")  
                elif i == self.wallp[0] and j == self.wallp[1]:
                    row.append("| W ")
                elif i == self.wallq[0] and j == self.wallq[1]:
                    row.append("| W ")
                elif i == self.wallr[0] and j == self.wallr[1]:
                    row.append("| W ")
                elif i == self.walls[0] and j == self.walls[1]:
                    row.append("| W ")
                elif i == self.wallt[0] and j == self.wallt[1]:
                    row.append("| W ")
                elif i == self.wallu[0] and j == self.wallu[1]:
                    row.append("| W ")
                elif i == self.wallv[0] and j == self.wallv[1]:
                    row.append("| W ")
                elif i == self.wallw[0] and j == self.wallw[1]:
                    row.append("| W ")
                elif i == self.wallx[0] and j == self.wallx[1]:
                    row.append("| W ")
                elif i == self.wally[0] and j == self.wally[1]:
                    row.append("| W ")
                elif i == self.wallz[0] and j == self.wallz[1]:
                    row.append("| W ")
                elif i == self.wallaa[0] and j == self.wallaa[1]:
                    row.append("| W ")
                elif i == self.wallbb[0] and j == self.wallbb[1]:
                    row.append("| W ")
                elif i == self.wallcc[0] and j == self.wallcc[1]:
                    row.append("| W ")
                elif i == self.walldd[0] and j == self.walldd[1]:
                    row.append("| W ")
                elif i == self.wallee[0] and j == self.wallee[1]:
                    row.append("| W ")
                elif i == self.wallff[0] and j == self.wallff[1]:
                    row.append("| W ")
                elif i == self.wallgg[0] and j == self.wallgg[1]:
                    row.append("| W ")
                elif i == self.wallhh[0] and j == self.wallhh[1]:
                    row.append("| W ")
                elif i == self.wallii[0] and j == self.wallii[1]:
                    row.append("| W ")
                elif i == self.walljj[0] and j == self.walljj[1]:
                    row.append("| W ")
                elif i == self.wallkk[0] and j == self.wallkk[1]:
                    row.append("| W ")
                elif i == self.wallll[0] and j == self.wallll[1]:
                    row.append("| W ")
                elif i == self.wallmm[0] and j == self.wallmm[1]:
                    row.append("| W ")
                elif i == self.wallnn[0] and j == self.wallnn[1]:
                    row.append("| W ")
                elif i == self.walloo[0] and j == self.walloo[1]:
                    row.append("| W ")
                elif i == self.wallpp[0] and j == self.wallpp[1]:
                    row.append("| W ")
                elif i == self.wallqq[0] and j == self.wallqq[1]:
                    row.append("| W ")
                elif i == self.wallrr[0] and j == self.wallrr[1]:
                    row.append("| W ")
                elif i == self.wallss[0] and j == self.wallss[1]:
                    row.append("| W ")
                elif i == self.walltt[0] and j == self.walltt[1]:
                    row.append("| W ")
                elif i == self.walluu[0] and j == self.walluu[1]:
                    row.append("| W ")
                elif i == self.wallvv[0] and j == self.wallvv[1]:
                    row.append("| W ")
                elif i == self.wallww[0] and j == self.wallww[1]:
                    row.append("| W ")
                elif i == self.wallxx[0] and j == self.wallxx[1]:
                    row.append("| W ")
                elif i == self.wallyy[0] and j == self.wallyy[1]:
                    row.append("| W ")
                elif i == self.wallzz[0] and j == self.wallzz[1]:
                    row.append("| W ")   
                elif i == self.wall1[0] and j == self.wall1[1]:
                    row.append("| W ")
                elif i == self.wall2[0] and j == self.wall2[1]:
                    row.append("| W ")
                elif i == self.wall3[0] and j == self.wall3[1]:
                    row.append("| W ")
                elif i == self.wall4[0] and j == self.wall4[1]:
                    row.append("| W ")
                elif i == self.wall5[0] and j == self.wall5[1]:
                    row.append("| W ")
                elif i == self.wall6[0] and j == self.wall6[1]:
                    row.append("| W ")
                elif i == self.wall7[0] and j == self.wall7[1]:
                    row.append("| W ")
                elif i == self.wall8[0] and j == self.wall8[1]:
                    row.append("| W ")
                elif i == self.wall9[0] and j == self.wall9[1]:
                    row.append("| W ")
                elif i == self.wall10[0] and j == self.wall10[1]:
                    row.append("| W ")
                elif i == self.wall11[0] and j == self.wall11[1]:
                    row.append("| W ")
                elif i == self.wall12[0] and j == self.wall12[1]:
                    row.append("| W ")    
                else:
                    row.append("|   ")
            row.append("|  ")
            print(' '.join(row))
        print("-" * (self.dim[0] * 5 + 1))
        
    # Give the agent an action
    def action(self, a):  
        if a not in self.action_space:  
            return "Error: Invalid action submission"
        # Check for special transition states
        if self.s == self.pos_A:
            self.reward = self.rew_A  
        elif self.s == self.wallA:
            self.reward = -1
        elif self.s == self.wallB:
            self.reward = -1
        elif self.s == self.wallC:
          self.reward = -1  
        elif self.s == self.wallD:
          self.reward = -1  
        elif self.s == self.wallE:
          self.reward = -1 
        elif self.s == self.wallF:
          self.reward = -1
        elif self.s == self.wallG:
          self.reward = -1  
        elif self.s == self.wallH:
          self.reward = -1    
        elif self.s == self.wallI:
            self.reward = -1
        elif self.s == self.wallJ:
            self.reward = -1
        elif self.s == self.wallK:
            self.reward = -1  
        elif self.s == self.wallL:
            self.reward = -1  
        elif self.s == self.wallM:
            self.reward = -1 
        elif self.s == self.wallN:
            self.reward = -1
        elif self.s == self.wallO:
            self.reward = -1  
        elif self.s == self.wallP:
            self.reward = -1  
        elif self.s == self.wallQ:
            self.reward = -1 
        elif self.s == self.wallR:
            self.reward = -1
        elif self.s == self.wallS:
            self.reward = -1  
        elif self.s == self.wallT:
            self.reward = -1  
        elif self.s == self.wallU:
            self.reward = -1 
        elif self.s == self.wallV:
            self.reward = -1
        elif self.s == self.wallW:
            self.reward = -1  
        elif self.s == self.wallX:
            self.reward = -1  
        elif self.s == self.wallY:
            self.reward = -1 
        elif self.s == self.wallZ:
            self.reward = -1
        elif self.s == self.walla:
            self.reward = -1
        elif self.s == self.wallb:
            self.reward = -1
        elif self.s == self.wallc:
          self.reward = -1  
        elif self.s == self.walld:
          self.reward = -1  
        elif self.s == self.walle:
          self.reward = -1 
        elif self.s == self.wallf:
          self.reward = -1
        elif self.s == self.wallg:
          self.reward = -1  
        elif self.s == self.wallh:
          self.reward = -1    
        elif self.s == self.walli:
            self.reward = -1
        elif self.s == self.wallj:
            self.reward = -1
        elif self.s == self.wallk:
            self.reward = -1
        elif self.s == self.walll:
            self.reward = -1
        elif self.s == self.wallm:
            self.reward = -1
        elif self.s == self.walln:
            self.reward = -1
        elif self.s == self.wallo:
            self.reward = -1
        elif self.s == self.wallp:
            self.reward = -1
        elif self.s == self.wallq:
            self.reward = -1
        elif self.s == self.wallr:
            self.reward = -1
        elif self.s == self.walls:
            self.reward = -1
        elif self.s == self.wallt:
            self.reward = -1
        elif self.s == self.wallu:
            self.reward = -1
        elif self.s == self.wallv:
            self.reward = -1
        elif self.s == self.wallw:
            self.reward = -1
        elif self.s == self.wallx:
            self.reward = -1
        elif self.s == self.wally:
            self.reward = -1
        elif self.s == self.wallz:
            self.reward = -1
        elif self.s == self.wallaa:
            self.reward = -1
        elif self.s == self.wallbb:
            self.reward = -1
        elif self.s == self.wallcc:
            self.reward = -1
        elif self.s == self.walldd:
            self.reward = -1
        elif self.s == self.wallee:
            self.reward = -1
        elif self.s == self.wallff:
            self.reward = -1
        elif self.s == self.wallgg:
            self.reward = -1
        elif self.s == self.wallhh:
            self.reward = -1
        elif self.s == self.wallii:
            self.reward = -1
        elif self.s == self.walljj:
            self.reward = -1
        elif self.s == self.wallkk:
            self.reward = -1
        elif self.s == self.wallll:
            self.reward = -1
        elif self.s == self.wallmm:
            self.reward = -1
        elif self.s == self.wallnn:
            self.reward = -1
        elif self.s == self.walloo:
            self.reward = -1
        elif self.s == self.wallpp:
            self.reward = -1
        elif self.s == self.wallqq:
            self.reward = -1
        elif self.s == self.wallrr:
            self.reward = -1
        elif self.s == self.wallss:
            self.reward = -1
        elif self.s == self.walltt:
            self.reward = -1
        elif self.s == self.walluu:
            self.reward = -1
        elif self.s == self.wallvv:
            self.reward = -1
        elif self.s == self.wallww:
            self.reward = -1
        elif self.s == self.wallxx:
            self.reward = -1
        elif self.s == self.wallyy:
            self.reward = -1
        elif self.s == self.wallzz:
            self.reward = -1
        elif self.s == self.wall1:
            self.reward = -1
        elif self.s == self.wall2:
            self.reward = -1
        elif self.s == self.wall3:
            self.reward = -1
        elif self.s == self.wall4:
            self.reward = -1
        elif self.s == self.wall5:
            self.reward = -1
        elif self.s == self.wall6:
            self.reward = -1
        elif self.s == self.wall7:
            self.reward = -1
        elif self.s == self.wall8:
            self.reward = -1
        elif self.s == self.wall9:
            self.reward = -1
        elif self.s == self.wall10:
            self.reward = -1
        elif self.s == self.wall11:
            self.reward = -1
        elif self.s == self.wall12:
            self.reward = -1


        # Move up
        elif a == "U" and self.s[0] > 0:
              self.s[0] -= 1
              self.reward = 0      
        # Move left
        elif a == "L" and self.s[1] > 0:
            self.s[1] -= 1
            self.reward = 0
        # Move down
        elif a == "D" and self.s[0] < self.dim[0] - 1:
            self.s[0] += 1
            self.reward = 0
        # Move right
        elif a == "R" and self.s[1] < self.dim[1] - 1:
            self.s[1] += 1
            self.reward = 0
        else:
            self.reward = -1
        self.n += 1
        return self.s, self.reward
            
    def reset(self):
        self.s = self.start
        self.reward = 0
        self.n = 0

# %% [markdown]
# We can view the environment with the show_grid() method or use the show_state() method to see where the agent is.

# %%
grid = gridworld()
grid.show_grid()
# Out:
# ------------------------------------------------------------------
# | W  | W  | W  | W  | W  | W  | W  | W  |    | W  | W  | W  |
# ------------------------------------------------------------------
# | W  |    |    |    |    |    |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  | W  | W  | W  | W  | W  |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | A  |    |    |    |    |    |    | W  |    |    |    | W  |
# ------------------------------------------------------------------
# | W  | W  | W  |    | W  | W  | W  | W  | W  | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    |    |    | W  |    |    |    |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    | W  |    | W  | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    | W  |    |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    | W  | W  |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    |    |    |    | W  |    |    |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  | W  | W  | W  | W  | W  | W  | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    |    |    |    |    |    |    | S  | W  |
# ------------------------------------------------------------------
# | W  | W  | W  | W  | W  | W  | W  | W  | W  | W  | W  | W  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
grid.show_state()
# Out:
# ------------------------------------------------------------------
# | W  | W  | W  | W  | W  | W  | W  | W  |    | W  | W  | W  |
# ------------------------------------------------------------------
# | W  |    |    |    |    |    |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  | W  | W  | W  | W  | W  |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | A  |    |    |    |    |    |    | W  |    |    |    | W  |
# ------------------------------------------------------------------
# | W  | W  | W  |    | W  | W  | W  | W  | W  | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    |    |    | W  |    |    |    |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    | W  |    | W  | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    | W  |    |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    | W  | W  |    | W  |    | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    |    |    |    | W  |    |    |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  | W  | W  | W  | W  | W  | W  | W  |    | W  |
# ------------------------------------------------------------------
# | W  |    | W  |    |    |    |    |    |    |    | X  | W  |
# ------------------------------------------------------------------
# | W  | W  | W  | W  | W  | W  | W  | W  | W  | W  | W  | W  |
# ------------------------------------------------------------------

# %% [markdown]
# # Value Function

# %%
v = np.zeros(grid.dim)
gamma = 0.9
delta = 1e-5
delta_t = 1

while delta_t > delta:
    v_new = np.zeros(grid.dim)
    for i in range(grid.dim[0]):
        for j in range(grid.dim[1]):
            for action in grid.action_space:
                grid.s = [i, j]
                s, r = grid.action(action)
                prob = grid.action_prob[grid.action_space.index(action)]
                v_new[i, j] += prob * (r + gamma * v[s[0], s[1]])
    delta_t = np.sum(np.abs(v - v_new))
    v = v_new.copy()
    
print(v.round(1))
# Out:
# [[-10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.   -8.5 -10.  -10.  -10. ]
#  [-10.   -8.6  -8.3  -8.2  -8.2  -8.2  -8.2 -10.   -8.3 -10.   -8.6 -10. ]
#  [-10.  -10.  -10.  -10.  -10.  -10.   -8.2 -10.   -8.2 -10.   -8.2 -10. ]
#  [150.   29.5   0.9  -5.4  -7.5  -8.   -8.1 -10.   -8.2  -8.1  -7.7 -10. ]
#  [-10.  -10.  -10.   -7.4 -10.  -10.  -10.  -10.  -10.  -10.   -8.1 -10. ]
#  [-10.   -8.1  -8.   -7.5 -10.   -8.2  -8.2  -8.2  -8.2 -10.   -8.2 -10. ]
#  [-10.   -8.2 -10.   -8.  -10.   -8.2 -10.  -10.   -8.2 -10.   -8.2 -10. ]
#  [-10.   -8.2 -10.   -8.1 -10.   -8.2  -8.2 -10.   -8.2 -10.   -8.2 -10. ]
#  [-10.   -8.2 -10.   -8.2 -10.  -10.   -8.2 -10.   -8.2 -10.   -8.1 -10. ]
#  [-10.   -8.2 -10.   -8.2  -8.2  -8.2  -8.2 -10.   -8.2  -8.1  -7.7 -10. ]
#  [-10.   -8.3 -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.   -8.1 -10. ]
#  [-10.   -8.6 -10.   -8.6  -8.3  -8.2  -8.2  -8.2  -8.2  -8.2  -8.2 -10. ]
#  [-10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10. ]]

# %%
q = np.zeros((grid.dim[0], grid.dim[1], len(grid.action_space)))
delta_t = 1

while delta_t > delta:
    q_old = q.copy()
    for i in range(grid.dim[0]):
        for j in range(grid.dim[1]):
            for a in grid.action_space:
                grid.s = [i, j]
                s, r = grid.action(a)
                a_index = grid.action_space.index(a)
                q[i, j, a_index] = r + gamma * np.max(q_old[s[0], s[1]])
    delta_t = np.sum(np.abs(q - q_old))
    
print(np.max(q, axis=2).round(1))
# Out:
# [[-10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.    3.  -10.  -10.  -10. ]
#  [-10.   38.1  42.4  47.1  52.3  58.1  64.6 -10.    3.4 -10.    4.2 -10. ]
#  [-10.  -10.  -10.  -10.  -10.  -10.   71.7 -10.    3.8 -10.    4.6 -10. ]
#  [150.  135.  121.5 109.3  98.4  88.6  79.7 -10.    4.2   4.6   5.2 -10. ]
#  [-10.  -10.  -10.   98.4 -10.  -10.  -10.  -10.  -10.  -10.    5.7 -10. ]
#  [-10.   71.7  79.7  88.6 -10.   25.   22.5  20.3  18.2 -10.    6.4 -10. ]
#  [-10.   64.6 -10.   79.7 -10.   27.8 -10.  -10.   16.4 -10.    7.1 -10. ]
#  [-10.   58.1 -10.   71.7 -10.   30.9  34.3 -10.   14.8 -10.    7.9 -10. ]
#  [-10.   52.3 -10.   64.6 -10.  -10.   38.1 -10.   13.3 -10.    8.7 -10. ]
#  [-10.   47.1 -10.   58.1  52.3  47.1  42.4 -10.   12.   10.8   9.7 -10. ]
#  [-10.   42.4 -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.    8.7 -10. ]
#  [-10.   38.1 -10.    3.8   4.2   4.6   5.2   5.7   6.4   7.1   7.9 -10. ]
#  [-10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10.  -10. ]]

# %% [markdown]
# # Optimal Policy

# %%
def opt_policy(q, grid):
    q_max = np.max(q, axis=2)
    x = np.linspace(0, grid.dim[0] - 1, grid.dim[1]) + 0.5
    y = np.linspace(grid.dim[1] - 1, 0, grid.dim[0]) + 0.5
    X, Y = np.meshgrid(x, y)
    zeros = np.zeros((grid.dim))
    
    fig = plt.figure(figsize=(20,16))
    ax = plt.axes()
    
    for i, action in enumerate(grid.action_space):
        q_star = np.zeros((13, 12))
        for j in range(grid.dim[0]):
            for k in reversed(range(grid.dim[1])):
                if q[j, k, i] == q_max[j, k]:
                    q_star[j, k] = 0.4
        # Plot results
        if action == "U":
            # Vectors point in positive Y-direction
            plt.quiver(X, Y, zeros, q_star, scale=1, units='xy')
        elif action == "L":
            # Vectors point in negative X-direction
            plt.quiver(X, Y, -q_star, zeros, scale=1, units='xy')
        elif action == "D":
            # Vectors point in negative Y-direction
            plt.quiver(X, Y, zeros, -q_star, scale=1, units='xy')
        elif action == "R":
            # Vectors point in positive X-direction
            plt.quiver(X, Y, q_star, zeros, scale=1, units='xy')
        
    plt.xlim([0, grid.dim[0]])
    plt.ylim([0, grid.dim[1]])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    plt.grid()
    plt.show()

# %%
opt_policy(q, grid)

# %% [markdown]
# ### NOTE: **13x13**
